# %%
import re
import time
import numpy as np
import pandas as pd
import spacy
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
import psycopg2
from sqlalchemy import create_engine

# %%
# !pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.1/en_core_sci_sm-0.5.1.tar.gz
# Out:
# Collecting https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.1/en_core_sci_sm-0.5.1.tar.gz
#   Using cached https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.1/en_core_sci_sm-0.5.1.tar.gz (15.9 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: spacy<3.5.0,>=3.4.1 in c:\users\mikita\anaconda3\lib\site-packages (from en-core-sci-sm==0.5.1) (3.4.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in c:\users\mikita\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\mikita\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\mikita\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\mikita\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\mikita\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in c:\users\mikita\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (8.1.12)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in c:\users\mikita\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\mikita\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\mikita\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (2.0.10)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in c:\users\mikita\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (0.7.0)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\mikita\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\mikita\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\mikita\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\mikita\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (1.24.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\mikita\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\mikita\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (1.10.8)
# Requirement already satisfied: jinja2 in c:\users\mikita\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\mikita\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\mikita\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\mikita\anaconda3\lib\site-packages (from spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\mikita\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (4.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mikita\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mikita\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mikita\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mikita\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\mikita\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\mikita\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (0.1.3)
# Requirement already satisfied: colorama in c:\users\mikita\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\mikita\anaconda3\lib\site-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mikita\anaconda3\lib\site-packages (from jinja2->spacy<3.5.0,>=3.4.1->en-core-sci-sm==0.5.1) (2.1.1)

# %%
# Загрузка модели для английского языка
nlp = spacy.load("en_core_sci_sm")

# %%
# Read the CSV files into dataframes
voc1_df = pd.read_csv('meddra_pt.csv')
voc2_df = pd.read_csv('SNOMED_OMOPext_CPT4_HCPCS.csv')
voc1_df=voc1_df[:10] # следующая 2000:4000
voc1_df = voc1_df.reset_index(drop=True)

# %%
voc1_df
# Out:
#                                             hierarchy  concept_id  \
# 0   Neoplasms benign, malignant and unspecified (i...    36617673
# 1   Neoplasms benign, malignant and unspecified (i...    36617674
# 2   Neoplasms benign, malignant and unspecified (i...    36617675
# 3   Neoplasms benign, malignant and unspecified (i...    36617676
# 4   Surgical and medical procedures(SOC)-Obstetric...    37521584
# 5   Neoplasms benign, malignant and unspecified (i...    36150289
# 6   Blood and lymphatic system disorders(SOC)-Neop...    35104568
# 7   Blood and lymphatic system disorders(SOC)-Neop...    35104569
# 8   Blood and lymphatic system disorders(SOC)-Neop...    35104570
# 9   Blood and lymphatic system disorders(SOC)-Neop...    35104571
# 10  Blood and lymphatic system disorders(SOC)-Neop...    35104572
# 11  Blood and lymphatic system disorders(SOC)-Neop...    35104573
# 12  Investigations(SOC)-Neurological, special sens...    36314919
# 13  Investigations(SOC)-Neurological, special sens...    36314920
# 14  Surgical and medical procedures(SOC)-Skin and ...    37521858
# 15  Pregnancy, puerperium and perinatal conditions...    36818731
# 16  Social circumstances(SOC)-Lifestyle issues(HLG...    37420562
# 17  Investigations(SOC)-Haematology investigations...    36313470
# 18  Investigations(SOC)-Reproductive organ and bre...    36315851
# 19  Investigations(SOC)-Reproductive organ and bre...    36315852
# 20  Investigations(SOC)-Reproductive organ and bre...    36315853
# 21  Investigations(SOC)-Gastrointestinal investiga...    36312676
# 22  Investigations(SOC)-Gastrointestinal investiga...    36312677
# 23  Investigations(SOC)-Gastrointestinal investiga...    36312678
# 24  Investigations(SOC)-Renal and urinary tract in...    36315739
# 25  General disorders and administration site cond...    35809376
# 26  Investigations(SOC)-Investigations, imaging an...    36313950
# 27  Investigations(SOC)-Investigations, imaging an...    36313951
# 28  Investigations(SOC)-Musculoskeletal and soft t...    36314880
# 29  Investigations(SOC)-Musculoskeletal and soft t...    36314881
#
#     concept_code                                 concept_name    domain_id  \
# 0       10047746                        Vulval cancer stage I    Condition
# 1       10047747                       Vulval cancer stage II    Condition
# 2       10047748                      Vulval cancer stage III    Condition
# 3       10047749                       Vulval cancer stage IV    Condition
# 4       10047772                         Vulval warts removal    Procedure
# 5       10047793                           Vulvovaginal warts    Condition
# 6       10047804   Waldenstrom's macroglobulinaemia recurrent    Condition
# 7       10047805  Waldenstrom's macroglobulinaemia refractory    Condition
# 8       10047806     Waldenstrom's macroglobulinaemia stage I    Condition
# 9       10047807    Waldenstrom's macroglobulinaemia stage II    Condition
# 10      10047808   Waldenstrom's macroglobulinaemia stage III    Condition
# 11      10047809    Waldenstrom's macroglobulinaemia stage IV    Condition
# 12      10047878              Weber tuning fork test abnormal  Measurement
# 13      10047882                Weber tuning fork test normal  Measurement
# 14      10047884                      Wedge resection toenail    Procedure
# 15      10047894                     Weight decrease neonatal    Condition
# 16      10047905                                Well educated  Observation
# 17      10047937       White blood cell agglutination present  Measurement
# 18      10047956                      White blood cells semen  Measurement
# 19      10047959             White blood cells semen negative  Measurement
# 20      10047960             White blood cells semen positive  Measurement
# 21      10047961                      White blood cells stool  Measurement
# 22      10047962             White blood cells stool negative  Measurement
# 23      10047963             White blood cells stool positive  Measurement
# 24      10047965             White blood cells urine negative  Measurement
# 25      10048007                      Withdrawal hypertension    Condition
# 26      10048065                               X-ray abnormal    Procedure
# 27      10048067                                 X-ray normal    Procedure
# 28      10048159                      X-ray of pelvis and hip    Procedure
# 29      10048160             X-ray of pelvis and hip abnormal    Procedure
#
#    concept_class_id
# 0                PT
# 1                PT
# 2                PT
# 3                PT
# 4                PT
# 5                PT
# 6                PT
# 7                PT
# 8                PT
# 9                PT
# 10               PT
# 11               PT
# 12               PT
# 13               PT
# 14               PT
# 15               PT
# 16               PT
# 17               PT
# 18               PT
# 19               PT
# 20               PT
# 21               PT
# 22               PT
# 23               PT
# 24               PT
# 25               PT
# 26               PT
# 27               PT
# 28               PT
# 29               PT

# %%
voc2_df
# Out:
#         concept_id                                       concept_name  \
# 0         36684768                    Drusen of bilateral optic discs
# 1         37110249     Microvascular embolism of arteriole (disorder)
# 2          4220821                                   Bronzed diabetes
# 3          4120412                              Level of psychoticism
# 4          4002835                             Bruising of oropharynx
# ...            ...                                                ...
# 564483     4036092                     ROM - Range of motion activity
# 564484    37309624  Low back pain co-occurrent with left side scia...
# 564485     4006806                           Miscarriage with uraemia
# 564486     4238036                                 Urological fistula
# 564487     4318113  Carbon monoxide poisoning from faulty furnace ...
#
#                                    concept_name_processed
# 0         ['drusen', 'of', 'bilateral', 'optic', 'discs']
# 1        ['microvascular', 'embolism', 'of', 'arteriole']
# 2                                   ['bronze', 'diabete']
# 3                         ['level', 'of', 'psychoticism']
# 4                        ['bruising', 'of', 'oropharynx']
# ...                                                   ...
# 564483       ['rom', 'range', 'of', 'motion', 'activity']
# 564484  ['low', 'back', 'pain', 'co', 'occurrent', 'wi...
# 564485                 ['miscarriage', 'with', 'uraemia']
# 564486                          ['urological', 'fistula']
# 564487  ['carbon', 'monoxide', 'poison', 'from', 'faul...
#
# [564488 rows x 3 columns]

# %%
# # words to remove from strings
# stop_words = ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd",
#              'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers',
#              'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what',
#              'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were',
#              'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the',
#              'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about',
#              'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from',
#              'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here',
#              'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other',
#              'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can',
#              'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain',
#              'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn',
#              "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn',
#              "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't",
#              'wouldn', "wouldn't",
#               # don't care  about right and left most of the time
#              #'right','left']

# %%
# Stop_words that were received from SciSpacy model (UMLS based)
stop_words = ["'d", "'ll", "'m", "'re", "'s", "'ve", 'a', 'about', 'above', 'across', 'after', 'afterwards', 'again',
              'against', 'all', 'almost', 'alone', 'along', 'already', 'also', 'although', 'always', 'am', 'among', 
              'amongst', 'amount', 'an', 'and', 'another', 'any', 'anyhow', 'anyone', 'anything', 'anyway', 
              'anywhere', 'are', 'around', 'as', 'at', 'back', 'be', 'became', 'because', 'become', 'becomes', 
              'becoming', 'been', 'before', 'beforehand', 'behind', 'being', 'below', 'beside', 'besides', 
              'between', 'beyond', 'both', 'bottom', 'but', 'by', 'ca', 'call', 'can', 'cannot', 'could', 'did', 
              'do', 'does', 'doing', 'done', 'down', 'due', 'during', 'each', 'eight', 'either', 'eleven', 'else', 
              'elsewhere', 'empty', 'enough', 'even', 'ever', 'every', 'everyone', 'everything', 'everywhere', 
              'except', 'few', 'fifteen', 'fifty', 'first', 'five', 'for', 'former', 'formerly', 'forty', 'four', 
              'from', 'front', 'full', 'further', 'get', 'give', 'go', 'had', 'has', 'have', 'he', 'hence', 'her', 
              'here', 'hereafter', 'hereby', 'herein', 'hereupon', 'hers', 'herself', 'him', 'himself', 'his', 'how', 
              'however', 'hundred', 'i', 'if', 'in', 'indeed', 'into', 'is', 'it', 'its', 'itself', 'just', 'keep', 
              'last', 'latter', 'latterly', 'least', 'less', 'made', 'make', 'many', 'may', 'me', 'meanwhile', 
              'might', 'mine', 'more', 'moreover', 'most', 'mostly', 'move', 'much', 'must', 'my', 'myself', "n't", 
              'name', 'namely', 'neither', 'never', 'nevertheless', 'next', 'nine', 'no', 'nobody', 'none', 'noone',
              'nor', 'not', 'nothing', 'now', 'nowhere', 'n‘t', 'n’t', 'of', 'off', 'often', 'on', 'once', 'one', 
              'only', 'onto', 'or', 'other', 'others', 'otherwise', 'our', 'ours', 'ourselves', 'out', 'over', 'own',
              'part', 'per', 'perhaps', 'please', 'put', 'quite', 'rather', 're', 'really', 'regarding', 'same',
              'say', 'see', 'seem', 'seemed', 'seeming', 'seems', 'serious', 'several', 'she', 'should', 'show',
              'side', 'since', 'six', 'sixty', 'so', 'some', 'somehow', 'someone', 'something', 'sometime',
              'sometimes', 'somewhere', 'still', 'such', 'take', 'ten', 'than', 'that', 'the', 'their', 'them', 
              'themselves', 'then', 'thence', 'there', 'thereafter', 'thereby', 'therefore', 'therein', 'thereupon',
              'these', 'they', 'third', 'this', 'those', 'though', 'three', 'through', 'throughout', 'thru', 'thus', 
              'to', 'together', 'too', 'top', 'toward', 'towards', 'twelve', 'twenty', 'two', 'under', 'unless', 
              'until', 'up', 'upon', 'us', 'used', 'using', 'various', 'very', 'via', 'was', 'we', 'well', 'were', 
              'what', 'whatever', 'when', 'whence', 'whenever', 'where', 'whereafter', 'whereas', 'whereby',
              'wherein', 'whereupon', 'wherever', 'whether', 'which', 'while', 'whither', 'who', 'whoever', 'whole',
              'whom', 'whose', 'why', 'will', 'with', 'within', 'without', 'would', 'yet', 'you', 'your', 'yours',
              'yourself', 'yourselves', '‘d', '‘ll', '‘m', '‘re', '‘s', '‘ve', '’d', '’ll', '’m', '’re', '’s', '’ve']

# aditional task-specific stop_words

stop_words = stop_words + ['noc', 'nos', '[d]', 'unknown_unit', '|', 'see comment', 'due', 'nec', 'unspecified', '[v]', '(see comments)',
              '(disorder)', '(procedure)', '(finding)', '(observable entity)']

# %%
# Convert the titles to lowercase
voc1_df['concept_name_processed'] = voc1_df['concept_name'].map(lambda x: str(x).lower())
voc2_df['concept_name_processed'] = voc2_df['concept_name'].map(lambda x: str(x).lower())


# Remove stopwords
voc1_df['concept_name_processed'] = voc1_df['concept_name_processed'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]))
voc2_df['concept_name_processed'] = voc2_df['concept_name_processed'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]))


# ignores weird symbols
voc1_df['concept_name_processed'] = voc1_df['concept_name_processed'].apply(lambda x: re.sub(r"\s+", " ", str(x).encode('ascii', 'ignore').decode()) if isinstance(x, str) else str(x))
voc2_df['concept_name_processed'] = voc2_df['concept_name_processed'].apply(lambda x: re.sub(r"\s+", " ", str(x).encode('ascii', 'ignore').decode()) if isinstance(x, str) else str(x))

# заменить '-' на ' '
#voc1_df['concept_name_processed'] = voc1_df['concept_name_processed'].map(lambda x: re.sub('-', ' ', x))
#voc2_df['concept_name_processed'] = voc2_df['concept_name_processed'].map(lambda x: re.sub('-', ' ', x))

# заменить '/' на ' '
voc1_df['concept_name_processed'] = voc1_df['concept_name_processed'].map(lambda x: re.sub('/', ' ', x))
voc2_df['concept_name_processed'] = voc2_df['concept_name_processed'].map(lambda x: re.sub('/', ' ', x))


# Remove punctuation, digits etc
voc1_df['concept_name_processed'] = voc1_df['concept_name_processed'].map(lambda x: re.sub('[,\.!;?)%(\'\":]', '', x))
voc2_df['concept_name_processed'] = voc2_df['concept_name_processed'].map(lambda x: re.sub('[,\.!;?)%(\'\":]', '', x))

# %%
voc1_df.head(5)
# Out:
#                                            hierarchy  concept_id  \
# 0  Neoplasms benign, malignant and unspecified (i...    36617673
# 1  Neoplasms benign, malignant and unspecified (i...    36617674
# 2  Neoplasms benign, malignant and unspecified (i...    36617675
# 3  Neoplasms benign, malignant and unspecified (i...    36617676
# 4  Surgical and medical procedures(SOC)-Obstetric...    37521584
#
#    concept_code             concept_name  domain_id concept_class_id  \
# 0      10047746    Vulval cancer stage I  Condition               PT
# 1      10047747   Vulval cancer stage II  Condition               PT
# 2      10047748  Vulval cancer stage III  Condition               PT
# 3      10047749   Vulval cancer stage IV  Condition               PT
# 4      10047772     Vulval warts removal  Procedure               PT
#
#     concept_name_processed
# 0    vulval cancer stage i
# 1   vulval cancer stage ii
# 2  vulval cancer stage iii
# 3   vulval cancer stage iv
# 4     vulval warts removal

# %%
voc2_df.head(5)
# Out:
#    concept_id                                    concept_name  \
# 0    36684768                 Drusen of bilateral optic discs
# 1    37110249  Microvascular embolism of arteriole (disorder)
# 2     4220821                                Bronzed diabetes
# 3     4120412                           Level of psychoticism
# 4     4002835                          Bruising of oropharynx
#
#                              concept_name_processed
# 0   ['drusen', 'of', 'bilateral', 'optic', 'discs']
# 1  ['microvascular', 'embolism', 'of', 'arteriole']
# 2                             ['bronze', 'diabete']
# 3                   ['level', 'of', 'psychoticism']
# 4                  ['bruising', 'of', 'oropharynx']

# %%
def tokenize_with_spacy(text):
    doc = nlp(text)
    tokens = [token.text for token in doc if not token.is_punct and not token.is_space]
    return tokens

start_time = time.time()

voc1_df['concept_name_processed'] = voc1_df['concept_name_processed'].apply(tokenize_with_spacy)
voc2_df['concept_name_processed'] = voc2_df['concept_name_processed'].apply(tokenize_with_spacy)

elapsed_time = (time.time() - start_time)/60
print(f"Total elapsed time for tokenization: {elapsed_time:.1f} minutes")


def lemmatize_with_spacy(text):
    doc = nlp(text)
    lemmatized_tokens = [token.lemma_ for token in doc]
    return lemmatized_tokens

start_time = time.time()

# Применение функции к вашему столбцу
voc1_df['concept_name_processed'] = voc1_df['concept_name_processed'].apply(lambda x: lemmatize_with_spacy(' '.join(x)))
voc2_df['concept_name_processed'] = voc2_df['concept_name_processed'].apply(lambda x: lemmatize_with_spacy(' '.join(x)))

elapsed_time = (time.time() - start_time)/60
print(f"Total elapsed time for lemmatization: {elapsed_time:.1f} minutes")
# Out:
# Total elapsed time for tokenization: 0.0 minutes
# Total elapsed time for lemmatization: 0.0 minutes

# %%
voc1_df.head()
# Out:
#                                            hierarchy  concept_id  \
# 0  Neoplasms benign, malignant and unspecified (i...    36617673
# 1  Neoplasms benign, malignant and unspecified (i...    36617674
# 2  Neoplasms benign, malignant and unspecified (i...    36617675
# 3  Neoplasms benign, malignant and unspecified (i...    36617676
# 4  Surgical and medical procedures(SOC)-Obstetric...    37521584
#
#    concept_code             concept_name  domain_id concept_class_id  \
# 0      10047746    Vulval cancer stage I  Condition               PT
# 1      10047747   Vulval cancer stage II  Condition               PT
# 2      10047748  Vulval cancer stage III  Condition               PT
# 3      10047749   Vulval cancer stage IV  Condition               PT
# 4      10047772     Vulval warts removal  Procedure               PT
#
#          concept_name_processed
# 0    [vulval, cancer, stage, I]
# 1   [vulval, cancer, stage, ii]
# 2  [vulval, cancer, stage, iii]
# 3   [vulval, cancer, stage, iv]
# 4       [vulval, wart, removal]

# %%
voc2_df.head()
# Out:
#    concept_id                                    concept_name  \
# 0    36684768                 Drusen of bilateral optic discs
# 1    37110249  Microvascular embolism of arteriole (disorder)
# 2     4220821                                Bronzed diabetes
# 3     4120412                           Level of psychoticism
# 4     4002835                          Bruising of oropharynx
#
#                              concept_name_processed
# 0   ['drusen', 'of', 'bilateral', 'optic', 'discs']
# 1  ['microvascular', 'embolism', 'of', 'arteriole']
# 2                             ['bronze', 'diabete']
# 3                   ['level', 'of', 'psychoticism']
# 4                  ['bruising', 'of', 'oropharynx']

# %%
# Save previously prepared vocabulary for future use
voc2_df.to_csv('SNOMED_OMOPext_CPT4_HCPCS_preprocessed.csv', index=False)

# %% [markdown]
# # TfIDF

# %%
# Preprocess and compute the TF-IDF document-term matrix for the snomed concepts
voc2_docs = voc2_df['concept_name_processed'].apply(lambda x: ''.join(x)).tolist()
tfidf_vectorizer = TfidfVectorizer()
voc2_dtm = tfidf_vectorizer.fit_transform(voc2_docs)

# Calculate cosine similarities and find 5 most similar snomed concepts for each meddra concept
results = []

batch_size = 10
num_top_matches = 10

start_time = time.time()
processed_count = 0

for voc1_index, voc1_row in voc1_df.iterrows():
    voc1_tokens = voc1_row['concept_name_processed']
    voc1_name = voc1_row['concept_name']
    voc1_concept_id = voc1_row['concept_id']

    voc1_text = ' '.join(voc1_tokens)
    voc1_dtm = tfidf_vectorizer.transform([voc1_text])

    similarities = cosine_similarity(voc1_dtm, voc2_dtm)[0]

    # Find indices of 5 most similar voc2 (SNOMED and etc.) concepts
    top_indices = np.argsort(similarities)[-num_top_matches:][::-1]

    for max_index in top_indices:
        voc2_concept_id = voc2_df.loc[max_index, 'concept_id']
        voc2_name = voc2_df.loc[max_index, 'concept_name']
        similarity = similarities[max_index]

        # Add a separate line of information to the results
        results.append((voc1_name, voc1_concept_id, voc2_concept_id, voc2_name, similarity))

    processed_count += 1
    if processed_count % batch_size == 0:
        elapsed_time = (time.time() - start_time) / 60
        print(f"Processed {processed_count} concepts in {elapsed_time:.1f} minutes")

# Sort the results by similarity in descending order
results.sort(key=lambda x: x[4], reverse=True)

# Convert results to DataFrame
columns = ['voc1_name', 'voc1_concept_id', 'voc2_concept_id', 'voc2_name', 'similarity']
results_df = pd.DataFrame(results, columns=columns)

elapsed_time = (time.time() - start_time) / 60
print(f"Total elapsed time: {elapsed_time:.1f} minutes")
# Out:
# Processed 10 concepts in 0.0 minutes
# Processed 20 concepts in 0.0 minutes
# Processed 30 concepts in 0.0 minutes
# Processed 40 concepts in 0.0 minutes
# Processed 50 concepts in 0.1 minutes
# Processed 60 concepts in 0.1 minutes
# Processed 70 concepts in 0.1 minutes
# Processed 80 concepts in 0.1 minutes
# Processed 90 concepts in 0.1 minutes
# Processed 100 concepts in 0.1 minutes
# Processed 110 concepts in 0.1 minutes
# Processed 120 concepts in 0.1 minutes
# Processed 130 concepts in 0.1 minutes
# Processed 140 concepts in 0.2 minutes
# Processed 150 concepts in 0.2 minutes
# Processed 160 concepts in 0.2 minutes
# Processed 170 concepts in 0.2 minutes
# Processed 180 concepts in 0.2 minutes
# Processed 190 concepts in 0.2 minutes
# Processed 200 concepts in 0.2 minutes
# Processed 210 concepts in 0.2 minutes
# Processed 220 concepts in 0.2 minutes
# Processed 230 concepts in 0.3 minutes
# Processed 240 concepts in 0.3 minutes
# Processed 250 concepts in 0.3 minutes
# Processed 260 concepts in 0.3 minutes
# Processed 270 concepts in 0.3 minutes
# Processed 280 concepts in 0.3 minutes
# Processed 290 concepts in 0.3 minutes
# Processed 300 concepts in 0.3 minutes
# Processed 310 concepts in 0.3 minutes
# Processed 320 concepts in 0.4 minutes
# Processed 330 concepts in 0.4 minutes
# Processed 340 concepts in 0.4 minutes
# Processed 350 concepts in 0.4 minutes
# Processed 360 concepts in 0.4 minutes
# Processed 370 concepts in 0.4 minutes
# Processed 380 concepts in 0.4 minutes
# Processed 390 concepts in 0.4 minutes
# Processed 400 concepts in 0.5 minutes
# Processed 410 concepts in 0.5 minutes
# Processed 420 concepts in 0.5 minutes
# Processed 430 concepts in 0.5 minutes
# Processed 440 concepts in 0.5 minutes
# Processed 450 concepts in 0.5 minutes
# Processed 460 concepts in 0.5 minutes
# Processed 470 concepts in 0.5 minutes
# Processed 480 concepts in 0.5 minutes
# Processed 490 concepts in 0.6 minutes
# Processed 500 concepts in 0.6 minutes
# Processed 510 concepts in 0.6 minutes
# Processed 520 concepts in 0.6 minutes
# Processed 530 concepts in 0.6 minutes
# Processed 540 concepts in 0.6 minutes
# Processed 550 concepts in 0.6 minutes
# Processed 560 concepts in 0.6 minutes
# Processed 570 concepts in 0.6 minutes
# Processed 580 concepts in 0.7 minutes
# Processed 590 concepts in 0.7 minutes
# Processed 600 concepts in 0.7 minutes
# Processed 610 concepts in 0.7 minutes
# Processed 620 concepts in 0.7 minutes
# Processed 630 concepts in 0.7 minutes
# Processed 640 concepts in 0.7 minutes
# Processed 650 concepts in 0.7 minutes
# Processed 660 concepts in 0.7 minutes
# Processed 670 concepts in 0.8 minutes
# Processed 680 concepts in 0.8 minutes
# Processed 690 concepts in 0.8 minutes
# Processed 700 concepts in 0.8 minutes
# Processed 710 concepts in 0.8 minutes
# Processed 720 concepts in 0.8 minutes
# Processed 730 concepts in 0.8 minutes
# Processed 740 concepts in 0.8 minutes
# Processed 750 concepts in 0.9 minutes
# Processed 760 concepts in 0.9 minutes
# Processed 770 concepts in 0.9 minutes
# Processed 780 concepts in 0.9 minutes
# Processed 790 concepts in 0.9 minutes
# Processed 800 concepts in 0.9 minutes
# Processed 810 concepts in 0.9 minutes
# Processed 820 concepts in 0.9 minutes
# Processed 830 concepts in 0.9 minutes
# Processed 840 concepts in 1.0 minutes
# Processed 850 concepts in 1.0 minutes
# Processed 860 concepts in 1.0 minutes
# Processed 870 concepts in 1.0 minutes
# Processed 880 concepts in 1.0 minutes
# Processed 890 concepts in 1.0 minutes
# Processed 900 concepts in 1.0 minutes
# Processed 910 concepts in 1.0 minutes
# Processed 920 concepts in 1.0 minutes
# Processed 930 concepts in 1.1 minutes
# Processed 940 concepts in 1.1 minutes
# Processed 950 concepts in 1.1 minutes
# Processed 960 concepts in 1.1 minutes
# Processed 970 concepts in 1.1 minutes
# Processed 980 concepts in 1.1 minutes
# Processed 990 concepts in 1.1 minutes
# Processed 1000 concepts in 1.1 minutes
# Processed 1010 concepts in 1.1 minutes
# Processed 1020 concepts in 1.2 minutes
# Processed 1030 concepts in 1.2 minutes
# Processed 1040 concepts in 1.2 minutes
# Processed 1050 concepts in 1.2 minutes
# Processed 1060 concepts in 1.2 minutes
# Processed 1070 concepts in 1.2 minutes
# Processed 1080 concepts in 1.2 minutes
# Processed 1090 concepts in 1.2 minutes
# Processed 1100 concepts in 1.2 minutes
# Processed 1110 concepts in 1.3 minutes
# Processed 1120 concepts in 1.3 minutes
# Processed 1130 concepts in 1.3 minutes
# Processed 1140 concepts in 1.3 minutes
# Processed 1150 concepts in 1.3 minutes
# Processed 1160 concepts in 1.3 minutes
# Processed 1170 concepts in 1.3 minutes
# Processed 1180 concepts in 1.3 minutes
# Processed 1190 concepts in 1.4 minutes
# Processed 1200 concepts in 1.4 minutes
# Processed 1210 concepts in 1.4 minutes
# Processed 1220 concepts in 1.4 minutes
# Processed 1230 concepts in 1.4 minutes
# Processed 1240 concepts in 1.4 minutes
# Processed 1250 concepts in 1.4 minutes
# Processed 1260 concepts in 1.4 minutes
# Processed 1270 concepts in 1.4 minutes
# Processed 1280 concepts in 1.5 minutes
# Processed 1290 concepts in 1.5 minutes
# Processed 1300 concepts in 1.5 minutes
# Processed 1310 concepts in 1.5 minutes
# Processed 1320 concepts in 1.5 minutes
# Processed 1330 concepts in 1.5 minutes
# Processed 1340 concepts in 1.5 minutes
# Processed 1350 concepts in 1.5 minutes
# Processed 1360 concepts in 1.5 minutes
# Processed 1370 concepts in 1.6 minutes
# Processed 1380 concepts in 1.6 minutes
# Processed 1390 concepts in 1.6 minutes
# Processed 1400 concepts in 1.6 minutes
# Processed 1410 concepts in 1.6 minutes
# Processed 1420 concepts in 1.6 minutes
# Processed 1430 concepts in 1.6 minutes
# Processed 1440 concepts in 1.6 minutes
# Processed 1450 concepts in 1.6 minutes
# Processed 1460 concepts in 1.7 minutes
# Processed 1470 concepts in 1.7 minutes
# Processed 1480 concepts in 1.7 minutes
# Processed 1490 concepts in 1.7 minutes
# Processed 1500 concepts in 1.7 minutes
# Processed 1510 concepts in 1.7 minutes
# Processed 1520 concepts in 1.7 minutes
# Processed 1530 concepts in 1.7 minutes
# Processed 1540 concepts in 1.8 minutes
# Processed 1550 concepts in 1.8 minutes
# Processed 1560 concepts in 1.8 minutes
# Processed 1570 concepts in 1.8 minutes
# Processed 1580 concepts in 1.8 minutes
# Processed 1590 concepts in 1.8 minutes
# Processed 1600 concepts in 1.8 minutes
# Processed 1610 concepts in 1.8 minutes
# Processed 1620 concepts in 1.8 minutes
# Processed 1630 concepts in 1.9 minutes
# Processed 1640 concepts in 1.9 minutes
# Processed 1650 concepts in 1.9 minutes
# Processed 1660 concepts in 1.9 minutes
# Processed 1670 concepts in 1.9 minutes
# Processed 1680 concepts in 1.9 minutes
# Processed 1690 concepts in 1.9 minutes
# Processed 1700 concepts in 1.9 minutes
# Processed 1710 concepts in 1.9 minutes
# Processed 1720 concepts in 2.0 minutes
# Processed 1730 concepts in 2.0 minutes
# Processed 1740 concepts in 2.0 minutes
# Processed 1750 concepts in 2.0 minutes
# Processed 1760 concepts in 2.0 minutes
# Processed 1770 concepts in 2.0 minutes
# Processed 1780 concepts in 2.0 minutes
# Processed 1790 concepts in 2.0 minutes
# Processed 1800 concepts in 2.1 minutes
# Processed 1810 concepts in 2.1 minutes
# Processed 1820 concepts in 2.1 minutes
# Processed 1830 concepts in 2.1 minutes
# Processed 1840 concepts in 2.1 minutes
# Processed 1850 concepts in 2.1 minutes
# Processed 1860 concepts in 2.1 minutes
# Processed 1870 concepts in 2.1 minutes
# Processed 1880 concepts in 2.1 minutes
# Processed 1890 concepts in 2.2 minutes
# Processed 1900 concepts in 2.2 minutes
# Processed 1910 concepts in 2.2 minutes
# Processed 1920 concepts in 2.2 minutes
# Processed 1930 concepts in 2.2 minutes
# Processed 1940 concepts in 2.2 minutes
# Processed 1950 concepts in 2.2 minutes
# Processed 1960 concepts in 2.2 minutes
# Processed 1970 concepts in 2.2 minutes
# Processed 1980 concepts in 2.3 minutes
# Processed 1990 concepts in 2.3 minutes
# Processed 2000 concepts in 2.3 minutes
# Total elapsed time: 2.3 minutes

# %%
# Output the results as a Pandas dataframe
df_sorted = results_df.sort_values(by=['voc1_name', 'similarity'], ascending=False)
df_sorted['origin']='TfIDF'
df_sorted.to_csv('final_table'+'_tfidf.csv', index=False)
df_sorted.head(50)
# Out:
#                                                voc1_name  voc1_concept_id  \
# 3289                             Vulval cancer recurrent         36617671
# 4769                             Vulval cancer recurrent         36617671
# 14219                            Vulval cancer recurrent         36617671
# 14502                            Vulval cancer recurrent         36617671
# 14503                            Vulval cancer recurrent         36617671
# 15389                            Vulval cancer recurrent         36617671
# 16114                            Vulval cancer recurrent         36617671
# 16115                            Vulval cancer recurrent         36617671
# 16323                            Vulval cancer recurrent         36617671
# 16496                            Vulval cancer recurrent         36617671
# 3676                            Vulval cancer metastatic         36617670
# 4368                            Vulval cancer metastatic         36617670
# 10672                           Vulval cancer metastatic         36617670
# 11039                           Vulval cancer metastatic         36617670
# 12301                           Vulval cancer metastatic         36617670
# 12463                           Vulval cancer metastatic         36617670
# 12637                           Vulval cancer metastatic         36617670
# 12652                           Vulval cancer metastatic         36617670
# 13044                           Vulval cancer metastatic         36617670
# 13246                           Vulval cancer metastatic         36617670
# 7160       Vitamin A deficiency related corneal disorder         35606879
# 7161       Vitamin A deficiency related corneal disorder         35606879
# 10200      Vitamin A deficiency related corneal disorder         35606879
# 10201      Vitamin A deficiency related corneal disorder         35606879
# 10705      Vitamin A deficiency related corneal disorder         35606879
# 10706      Vitamin A deficiency related corneal disorder         35606879
# 10707      Vitamin A deficiency related corneal disorder         35606879
# 10708      Vitamin A deficiency related corneal disorder         35606879
# 10709      Vitamin A deficiency related corneal disorder         35606879
# 10710      Vitamin A deficiency related corneal disorder         35606879
# 11613  Vitamin A deficiency related conjunctival diso...         35606850
# 11614  Vitamin A deficiency related conjunctival diso...         35606850
# 12186  Vitamin A deficiency related conjunctival diso...         35606850
# 12187  Vitamin A deficiency related conjunctival diso...         35606850
# 12188  Vitamin A deficiency related conjunctival diso...         35606850
# 12189  Vitamin A deficiency related conjunctival diso...         35606850
# 12190  Vitamin A deficiency related conjunctival diso...         35606850
# 12191  Vitamin A deficiency related conjunctival diso...         35606850
# 12192  Vitamin A deficiency related conjunctival diso...         35606850
# 12193  Vitamin A deficiency related conjunctival diso...         35606850
# 7884                   Vital dye staining cornea present         36315210
# 13171                  Vital dye staining cornea present         36315210
# 18413                  Vital dye staining cornea present         36315210
# 18414                  Vital dye staining cornea present         36315210
# 18957                  Vital dye staining cornea present         36315210
# 18958                  Vital dye staining cornea present         36315210
# 19072                  Vital dye staining cornea present         36315210
# 19073                  Vital dye staining cornea present         36315210
# 19154                  Vital dye staining cornea present         36315210
# 19155                  Vital dye staining cornea present         36315210
#
#        voc2_concept_id                                          voc2_name  \
# 3289            195197                              Primary vulval cancer
# 4769            764225                                   Recurrent cancer
# 14219           442259                                    Vulval disorder
# 14502         37208178                Recurrent ovarian cancer (disorder)
# 14503         37208178                           Recurrent ovarian cancer
# 15389          4172084                                      Vulval biopsy
# 16114          4012199                              Vulval pain (finding)
# 16115          4012199                                        Vulval pain
# 16323           606881                        At risk of recurrent cancer
# 16496           434084                                     Vulval abscess
# 3676            195197                              Primary vulval cancer
# 4368            432851                                  Metastatic cancer
# 10672           136354                          Cancer metastatic to skin
# 11039            78097                          Cancer metastatic to bone
# 12301          4247967                         Cancer metastatic to heart
# 12463          4196262                         Metastatic prostate cancer
# 12637           196053                        Cancer metastatic to kidney
# 12652           254591                          Cancer metastatic to lung
# 13044           198700                         Cancer metastatic to liver
# 13246          4246451                         Cancer metastatic to brain
# 7160          37116565  Corneal ulcer due to vitamin A deficiency (dis...
# 7161          37116565          Corneal ulcer due to vitamin A deficiency
# 10200          4182543   Vitamin deficiency related neuropathy (disorder)
# 10201          4182543              Vitamin deficiency related neuropathy
# 10705           438114                               Vitamin A deficiency
# 10706           435781                               Vitamin K deficiency
# 10707          4203927                    Vitamin E deficiency (disorder)
# 10708           437246                    Vitamin B deficiency (disorder)
# 10709           439787                               Vitamin C deficiency
# 10710           435781                    Vitamin K deficiency (disorder)
# 11613          4182543   Vitamin deficiency related neuropathy (disorder)
# 11614          4182543              Vitamin deficiency related neuropathy
# 12186           435781                               Vitamin K deficiency
# 12187          4242339                    Vitamin P deficiency (disorder)
# 12188           437246                    Vitamin B deficiency (disorder)
# 12189           437246                               Vitamin B deficiency
# 12190          4242339                               Vitamin P deficiency
# 12191           436658                      Vitamin deficiency (disorder)
# 12192           438114                               Vitamin A deficiency
# 12193          4203927                               Vitamin E deficiency
# 7884           4014629                                     Vital staining
# 13171          4014629                              Vital staining method
# 18413          4191229                     Fluorescein staining of cornea
# 18414          4191229           Fluorescein staining of cornea (finding)
# 18957         42537744                        Transplanted cornea present
# 18958         42537744              Transplanted cornea present (finding)
# 19072          4083301                         Staining of skin (finding)
# 19073          4083301                                   Staining of skin
# 19154          4124355      Intrinsic staining of tooth - non-vital tooth
# 19155          4124355  Intrinsic staining of tooth - non-vital tooth ...
#
#        similarity origin
# 3289     0.777719  TfIDF
# 4769     0.740397  TfIDF
# 14219    0.583841  TfIDF
# 14502    0.579575  TfIDF
# 14503    0.579575  TfIDF
# 15389    0.564193  TfIDF
# 16114    0.551910  TfIDF
# 16115    0.551910  TfIDF
# 16323    0.547587  TfIDF
# 16496    0.544525  TfIDF
# 3676     0.766127  TfIDF
# 4368     0.749371  TfIDF
# 10672    0.638191  TfIDF
# 11039    0.632470  TfIDF
# 12301    0.613798  TfIDF
# 12463    0.611537  TfIDF
# 12637    0.608340  TfIDF
# 12652    0.608145  TfIDF
# 13044    0.601622  TfIDF
# 13246    0.598500  TfIDF
# 7160     0.693731  TfIDF
# 7161     0.693731  TfIDF
# 10200    0.645961  TfIDF
# 10201    0.645961  TfIDF
# 10705    0.637392  TfIDF
# 10706    0.637392  TfIDF
# 10707    0.637392  TfIDF
# 10708    0.637392  TfIDF
# 10709    0.637392  TfIDF
# 10710    0.637392  TfIDF
# 11613    0.623426  TfIDF
# 11614    0.623426  TfIDF
# 12186    0.615156  TfIDF
# 12187    0.615156  TfIDF
# 12188    0.615156  TfIDF
# 12189    0.615156  TfIDF
# 12190    0.615156  TfIDF
# 12191    0.615156  TfIDF
# 12192    0.615156  TfIDF
# 12193    0.615156  TfIDF
# 7884     0.681634  TfIDF
# 13171    0.599597  TfIDF
# 18413    0.480743  TfIDF
# 18414    0.480743  TfIDF
# 18957    0.437718  TfIDF
# 18958    0.437718  TfIDF
# 19072    0.422373  TfIDF
# 19073    0.422373  TfIDF
# 19154    0.412317  TfIDF
# 19155    0.412317  TfIDF

# %%
df_tfidf=df_sorted

# %% [markdown]
# # Fuzz_ratio

# %% [markdown]
# **Rapidfuzz.fuzz.ratio** is a function from the rapidfuzz library in Python, which is used for string matching and similarity comparisons. The rapidfuzz library is known for its efficient and fast computation of string similarities, often utilized in scenarios where large datasets require rapid processing of string comparison tasks.
#
# The fuzz.ratio function computes the similarity between two strings, returning a score that represents how similar the two strings are. The score is an integer ranging from 0 to 100, where 100 indicates an exact match (the strings are identical), and lower scores indicate less similarity.
#
# This function implements an algorithm similar to the Levenshtein Distance, which calculates the number of single-character edits (insertions, deletions, or substitutions) required to change one word into the other. However, rapidfuzz has optimized the computation for performance, making it faster than many other implementations of similar algorithms.
#
# In summary, rapidfuzz.fuzz.ratio is a fast and efficient way to compare two strings and quantify their similarity, widely used in tasks like data cleaning, deduplication, and matching in various applications.

# %%
#!pip install python-Levenshtein
# Out:
# Requirement already satisfied: python-Levenshtein in c:\users\mikita\anaconda3\lib\site-packages (0.22.0)
# Requirement already satisfied: Levenshtein==0.22.0 in c:\users\mikita\anaconda3\lib\site-packages (from python-Levenshtein) (0.22.0)
# Requirement already satisfied: rapidfuzz<4.0.0,>=2.3.0 in c:\users\mikita\anaconda3\lib\site-packages (from Levenshtein==0.22.0->python-Levenshtein) (3.3.1)

# %%
#import Levenshtein as lev

# %%
voc1_df['concept_name_processed'] = voc1_df['concept_name_processed'].apply(lambda x: sorted(x))
voc2_df['concept_name_processed'] = voc2_df['concept_name_processed'].apply(lambda x: x.strip("[]").replace("'", "").split(', '))
voc2_df['concept_name_processed'] = voc2_df['concept_name_processed'].apply(lambda x: sorted(x))

# %%
voc2_df.head(10)
# Out:
#    concept_id                                       concept_name  \
# 0    36684768                    Drusen of bilateral optic discs
# 1    37110249     Microvascular embolism of arteriole (disorder)
# 2     4220821                                   Bronzed diabetes
# 3     4120412                              Level of psychoticism
# 4     4002835                             Bruising of oropharynx
# 5     4336536                Dilation of nasopharynx (procedure)
# 6     4232889              Discharge readiness: supported living
# 7     4013513                         Cardiovascular measurement
# 8    36715972                     Human herpesvirus 4 meningitis
# 9     4018600  Complement C1 esterase inhibitor, total measur...
#
#                               concept_name_processed
# 0              [bilateral, discs, drusen, of, optic]
# 1           [arteriole, embolism, microvascular, of]
# 2                                  [bronze, diabete]
# 3                          [level, of, psychoticism]
# 4                         [bruising, of, oropharynx]
# 5                        [dilation, nasopharynx, of]
# 6              [discharge, live, readiness, support]
# 7                      [cardiovascular, measurement]
# 8                [4, herpesvirus, human, meningitis]
# 9  [c1, complement, esterase, inhibitor, measurem...

# %%
# # Old variant of Levenshtein
# start_time = time.time()
# results = []

# count = 0
# num_top_matches = 10  # Указываем количество ближайших совпадений, которые мы хотим сохранить

# for voc1_index, voc1_row in voc1_df.iterrows():
#     voc1_name = voc1_row['concept_name']
#     voc1_concept_id=voc1_row['concept_id']
#     voc1_tokens = voc1_row['concept_name_processed']

#     min_distances = [float('inf')] * num_top_matches  # Список для хранения наименьших расстояний
#     top_matches = [[] for _ in range(num_top_matches)]  # Список для хранения ближайших сочетаний

#     for voc2_index, voc2_row in voc2_df.iterrows():
#         voc2_concept_id = voc2_row['concept_id']
#         voc2_name = voc2_row['concept_name_processed']

#         # Calculate Levenshtein distance between voc1 and voc2 concept names
#         distance = lev.distance(''.join(voc1_tokens), ''.join(voc2_name))

#         # Обновляем ближайшие совпадения, если найдено более близкое совпадение
#         for i in range(num_top_matches):
#             if distance < min_distances[i]:
#                 min_distances.insert(i, distance)
#                 min_distances.pop()
#                 top_matches.insert(i, (voc2_concept_id, voc2_row['concept_name'], distance))
#                 top_matches.pop()
#                 break

#     # Сортируем top_matches по возрастанию min_distance перед добавлением в results
#     top_matches.sort(key=lambda x: x[2])

#     # Добавляем ближайшие совпадения в результаты
#     for matches in top_matches:
#         if matches:  # Проверяем, что список не пустой
#             voc2_concept_id, voc2_name, min_distance = matches
#             results.append((voc1_name, voc1_concept_id, voc2_concept_id, voc2_name, min_distance))

#     count += 1
#     if count % 10 == 0:
#         elapsed_time = (time.time() - start_time) / 60
#         print(f"Elapsed time: {elapsed_time:.1f} minutes for {count} концептов")

# # Convert results to DataFrame
# columns = ['voc1_name', 'voc1_concept_id', 'voc2_concept_id', 'voc2_name', 'min_distance']
# results_df = pd.DataFrame(results, columns=columns)

# elapsed_time = (time.time() - start_time) / 60
# print(f"Total elapsed time: {elapsed_time:.1f} minutes")
# Out:
# Elapsed time: 10.0 minutes for 10 концептов
# Elapsed time: 20.4 minutes for 20 концептов
# Elapsed time: 30.8 minutes for 30 концептов
# Total elapsed time: 30.8 minutes

# %%
# # Output the results as a Pandas dataframe
# df_sorted = results_df.sort_values(by=['voc1_name', 'min_distance'], ascending=True)
# df_sorted['origin']='Levenshtein_distance'
# df_sorted.to_csv('final_table'+'_levenshtein_old.csv', index=False)
# df_sorted.head(50)
# Out:
#                   voc1_name  voc1_concept_id  voc2_concept_id  \
# 0     Vulval cancer stage I         36617673          4178959
# 1     Vulval cancer stage I         36617673           195197
# 2     Vulval cancer stage I         36617673          4195031
# 3     Vulval cancer stage I         36617673         40480197
# 4     Vulval cancer stage I         36617673          4294557
# 5     Vulval cancer stage I         36617673          4195031
# 6     Vulval cancer stage I         36617673          4294557
# 7     Vulval cancer stage I         36617673           198984
# 8     Vulval cancer stage I         36617673          4221654
# 9     Vulval cancer stage I         36617673           443398
# 10   Vulval cancer stage II         36617674           195197
# 11   Vulval cancer stage II         36617674         40480197
# 12   Vulval cancer stage II         36617674          4178959
# 13   Vulval cancer stage II         36617674           443398
# 14   Vulval cancer stage II         36617674          4116086
# 15   Vulval cancer stage II         36617674           438386
# 16   Vulval cancer stage II         36617674           444106
# 17   Vulval cancer stage II         36617674          4297643
# 18   Vulval cancer stage II         36617674          4294557
# 19   Vulval cancer stage II         36617674          4294557
# 20  Vulval cancer stage III         36617675           195197
# 21  Vulval cancer stage III         36617675          4116086
# 22  Vulval cancer stage III         36617675           438386
# 23  Vulval cancer stage III         36617675         40480197
# 24  Vulval cancer stage III         36617675          4178959
# 25  Vulval cancer stage III         36617675           443398
# 26  Vulval cancer stage III         36617675          4181343
# 27  Vulval cancer stage III         36617675           444106
# 28  Vulval cancer stage III         36617675           444106
# 29  Vulval cancer stage III         36617675          4297643
# 30   Vulval cancer stage IV         36617676           195197
# 31   Vulval cancer stage IV         36617676         40480197
# 32   Vulval cancer stage IV         36617676          4178959
# 33   Vulval cancer stage IV         36617676           443398
# 34   Vulval cancer stage IV         36617676          4116086
# 35   Vulval cancer stage IV         36617676           438386
# 36   Vulval cancer stage IV         36617676           444106
# 37   Vulval cancer stage IV         36617676          4181343
# 38   Vulval cancer stage IV         36617676          4181343
# 39   Vulval cancer stage IV         36617676         40487046
# 40     Vulval warts removal         37521584          4130346
# 41     Vulval warts removal         37521584          4130346
# 42     Vulval warts removal         37521584         46270984
# 43     Vulval warts removal         37521584          4224170
# 44     Vulval warts removal         37521584          4259343
# 45     Vulval warts removal         37521584          4134598
# 46     Vulval warts removal         37521584          4224170
# 47     Vulval warts removal         37521584          4123445
# 48     Vulval warts removal         37521584          4123445
# 49     Vulval warts removal         37521584          4134598
#
#                          voc2_name  min_distance                origin
# 0                  Cancer of vulva             7  Levenshtein_distance
# 1            Primary vulval cancer             7  Levenshtein_distance
# 2   Taking vulval swab (procedure)             8  Levenshtein_distance
# 3                  Interval cancer             8  Levenshtein_distance
# 4      Vulval chancroid (disorder)             8  Levenshtein_distance
# 5               Taking vulval swab             8  Levenshtein_distance
# 6                 Vulval chancroid             8  Levenshtein_distance
# 7                  Cervical cancer             9  Levenshtein_distance
# 8         Vulval eczema (disorder)             9  Levenshtein_distance
# 9                Intestinal cancer             9  Levenshtein_distance
# 10           Primary vulval cancer             6  Levenshtein_distance
# 11                 Interval cancer             7  Levenshtein_distance
# 12                 Cancer of vulva             8  Levenshtein_distance
# 13               Intestinal cancer             8  Levenshtein_distance
# 14     Paget disease vulvar cancer             8  Levenshtein_distance
# 15         Cancer in situ of vulva             8  Levenshtein_distance
# 16              Vulval candidiasis             8  Levenshtein_distance
# 17          Vulval Crohn's disease             8  Levenshtein_distance
# 18     Vulval chancroid (disorder)             8  Levenshtein_distance
# 19                Vulval chancroid             8  Levenshtein_distance
# 20           Primary vulval cancer             6  Levenshtein_distance
# 21     Paget disease vulvar cancer             8  Levenshtein_distance
# 22         Cancer in situ of vulva             8  Levenshtein_distance
# 23                 Interval cancer             8  Levenshtein_distance
# 24                 Cancer of vulva             9  Levenshtein_distance
# 25               Intestinal cancer             9  Levenshtein_distance
# 26               Esophageal cancer             9  Levenshtein_distance
# 27               Vulval candidosis             9  Levenshtein_distance
# 28              Vulval candidiasis             9  Levenshtein_distance
# 29          Vulval Crohn's disease             9  Levenshtein_distance
# 30           Primary vulval cancer             6  Levenshtein_distance
# 31                 Interval cancer             7  Levenshtein_distance
# 32                 Cancer of vulva             8  Levenshtein_distance
# 33               Intestinal cancer             8  Levenshtein_distance
# 34     Paget disease vulvar cancer             8  Levenshtein_distance
# 35         Cancer in situ of vulva             8  Levenshtein_distance
# 36              Vulval candidiasis             8  Levenshtein_distance
# 37              Oesophageal cancer             9  Levenshtein_distance
# 38               Esophageal cancer             9  Levenshtein_distance
# 39              Carcinoma of vulva             9  Levenshtein_distance
# 40         Vulval warts (disorder)             7  Levenshtein_distance
# 41                    Vulval warts             7  Levenshtein_distance
# 42            Sternal wire removal             7  Levenshtein_distance
# 43                  Splint removal             8  Levenshtein_distance
# 44               Teach wax removal             8  Levenshtein_distance
# 45                Surgical removal             8  Levenshtein_distance
# 46      Splint removal (procedure)             8  Levenshtein_distance
# 47     Removal of wart (procedure)             8  Levenshtein_distance
# 48                 Removal of wart             8  Levenshtein_distance
# 49    Surgical removal (procedure)             8  Levenshtein_distance

# %%
# !pip install rapidfuzz
import rapidfuzz
# Out:
# Requirement already satisfied: rapidfuzz in c:\users\mikita\anaconda3\lib\site-packages (3.3.1)

# %%
# new version from ChatGPT
import time
import pandas as pd
import numpy as np
from rapidfuzz import process
import concurrent.futures

start_time = time.time()

num_top_matches = 10

# Preprocessing
voc1_df['voc1_tokens_str'] = voc1_df['concept_name_processed'].apply(''.join)
voc2_names = voc2_df['concept_name_processed'].apply(''.join).tolist()

# Define a function to process a chunk of rows
def process_chunk(chunk, voc2_names):
    results = []
    for _, voc1_row in chunk.iterrows():
        voc1_name = voc1_row['concept_name']
        voc1_concept_id = voc1_row['concept_id']
        voc1_tokens_str = voc1_row['voc1_tokens_str']

        # Get top matches using rapidfuzz
        top_matches = process.extract(voc1_tokens_str, voc2_names, limit=num_top_matches, scorer=rapidfuzz.fuzz.ratio)
        
        # Unpack the results correctly
        for match in top_matches:
            matched_string, score, index = match
            voc2_concept_id = voc2_df.iloc[index]['concept_id']
            voc2_name = voc2_df.iloc[index]['concept_name']
            results.append((voc1_name, voc1_concept_id, voc2_concept_id, voc2_name, score))
    
    return results

# Split DataFrame into chunks for parallel processing
chunk_size = 100  # Adjust this based on your DataFrame's size and available memory
chunks = [voc1_df.iloc[i:i + chunk_size] for i in range(0, voc1_df.shape[0], chunk_size)]

# Parallel processing of chunks
with concurrent.futures.ThreadPoolExecutor() as executor:
    results = list(executor.map(process_chunk, chunks, [voc2_names] * len(chunks)))

# Flatten the list of results
flattened_results = [item for sublist in results for item in sublist]

# Convert results to DataFrame
columns = ['voc1_name', 'voc1_concept_id', 'voc2_concept_id', 'voc2_name', 'fuzz_ration']
results_df = pd.DataFrame(flattened_results, columns=columns)

elapsed_time = (time.time() - start_time) / 60
print(f"Total elapsed time: {elapsed_time:.1f} minutes")
# Out:
# Total elapsed time: 0.1 minutes

# %%
results_df
# Out:
#                             voc1_name  voc1_concept_id  voc2_concept_id  \
# 0               Vulval cancer stage I         36617673          4116086
# 1               Vulval cancer stage I         36617673          4178959
# 2               Vulval cancer stage I         36617673          4181343
# 3               Vulval cancer stage I         36617673           195197
# 4               Vulval cancer stage I         36617673           438386
# ..                                ...              ...              ...
# 295  X-ray of pelvis and hip abnormal         36314881          4056699
# 296  X-ray of pelvis and hip abnormal         36314881         44783486
# 297  X-ray of pelvis and hip abnormal         36314881          4167549
# 298  X-ray of pelvis and hip abnormal         36314881          4056705
# 299  X-ray of pelvis and hip abnormal         36314881          4056705
#
#                                     voc2_name  fuzz_ration
# 0                 Paget disease vulvar cancer    71.428571
# 1                             Cancer of vulva    70.967742
# 2                           Esophageal cancer    70.588235
# 3                       Primary vulval cancer    70.270270
# 4                     Cancer in situ of vulva    70.270270
# ..                                        ...          ...
# 295                 Plain X-ray hand abnormal    70.833333
# 296         MRI of thorax, abdomen and pelvis    70.370370
# 297           CT of chest, abdomen and pelvis    69.387755
# 298            Plain X-ray hip joint abnormal    69.230769
# 299  Plain X-ray hip joint abnormal (finding)    69.230769
#
# [300 rows x 5 columns]

# %%
# Output the results as a Pandas dataframe
df_sorted = results_df.sort_values(by=['voc1_name', 'fuzz_ratio'], ascending=False)
df_sorted['origin']='fuzz_ratio'
df_sorted.to_csv('final_table'+'_fuzz_ratio.csv', index=False)
df_sorted.head(50)
# Out:
#                             voc1_name  voc1_concept_id  voc2_concept_id  \
# 290  X-ray of pelvis and hip abnormal         36314881          4222906
# 291  X-ray of pelvis and hip abnormal         36314881         37016203
# 292  X-ray of pelvis and hip abnormal         36314881         37018682
# 293  X-ray of pelvis and hip abnormal         36314881          4170261
# 294  X-ray of pelvis and hip abnormal         36314881          4056699
# 295  X-ray of pelvis and hip abnormal         36314881          4056699
# 296  X-ray of pelvis and hip abnormal         36314881         44783486
# 297  X-ray of pelvis and hip abnormal         36314881          4167549
# 298  X-ray of pelvis and hip abnormal         36314881          4056705
# 299  X-ray of pelvis and hip abnormal         36314881          4056705
# 280           X-ray of pelvis and hip         36314880          4222906
# 281           X-ray of pelvis and hip         36314880         37016698
# 282           X-ray of pelvis and hip         36314880          4201351
# 283           X-ray of pelvis and hip         36314880          4222906
# 284           X-ray of pelvis and hip         36314880          4222906
# 285           X-ray of pelvis and hip         36314880         37117068
# 286           X-ray of pelvis and hip         36314880         36684408
# 287           X-ray of pelvis and hip         36314880         36717652
# 288           X-ray of pelvis and hip         36314880         36717652
# 289           X-ray of pelvis and hip         36314880          4145310
# 270                      X-ray normal         36313951          4059546
# 271                      X-ray normal         36313951          4124651
# 272                      X-ray normal         36313951          4124651
# 273                      X-ray normal         36313951          4233227
# 274                      X-ray normal         36313951          4101209
# 275                      X-ray normal         36313951          4220343
# 276                      X-ray normal         36313951          4220343
# 277                      X-ray normal         36313951          3654258
# 278                      X-ray normal         36313951          4220343
# 279                      X-ray normal         36313951          4217975
# 260                    X-ray abnormal         36313950          4310398
# 261                    X-ray abnormal         36313950          4310398
# 262                    X-ray abnormal         36313950          4013850
# 263                    X-ray abnormal         36313950          4233227
# 264                    X-ray abnormal         36313950          4221288
# 265                    X-ray abnormal         36313950          4007285
# 266                    X-ray abnormal         36313950          4007285
# 267                    X-ray abnormal         36313950           437643
# 268                    X-ray abnormal         36313950           440985
# 269                    X-ray abnormal         36313950           437643
# 250           Withdrawal hypertension         35809376           443771
# 251           Withdrawal hypertension         35809376           443771
# 252           Withdrawal hypertension         35809376          4118910
# 253           Withdrawal hypertension         35809376          4118910
# 254           Withdrawal hypertension         35809376         37110413
# 255           Withdrawal hypertension         35809376         37110413
# 256           Withdrawal hypertension         35809376           192680
# 257           Withdrawal hypertension         35809376           192680
# 258           Withdrawal hypertension         35809376         44811110
# 259           Withdrawal hypertension         35809376           192680
#
#                                           voc2_name  fuzz_ration  \
# 290                         X-ray of pelvis and hip    75.555556
# 291                          MRI of pelvis abnormal    73.913043
# 292                           CT of pelvis abnormal    71.111111
# 293                       MRI of abdomen and pelvis    70.833333
# 294             Plain X-ray hand abnormal (finding)    70.833333
# 295                       Plain X-ray hand abnormal    70.833333
# 296               MRI of thorax, abdomen and pelvis    70.370370
# 297                 CT of chest, abdomen and pelvis    69.387755
# 298                  Plain X-ray hip joint abnormal    69.230769
# 299        Plain X-ray hip joint abnormal (finding)    69.230769
# 280                         X-ray of pelvis and hip    91.891892
# 281                            CT of pelvis and hip    80.000000
# 282                           MRI of pelvis and hip    77.777778
# 283                Skeletal X-ray of pelvis and hip    75.555556
# 284    Skeletal X-ray of pelvis and hip (procedure)    75.555556
# 285                      CT of pelvis and right hip    75.000000
# 286                     MRI of pelvis and right hip    73.170732
# 287              X-ray tomography of pelvis and hip    72.340426
# 288  X-ray tomography of pelvis and hip (procedure)    72.340426
# 289                                 X-ray of pelvis    70.967742
# 270                              Chest X-ray normal    78.260870
# 271                          Normal ovary (finding)    72.727273
# 272                                    Normal ovary    72.727273
# 273                                   Panoral X-ray    72.727273
# 274                                   Throat normal    69.565217
# 275                         Retina normal (finding)    69.565217
# 276                                   Retina-normal    69.565217
# 277                                   Normal thorax    69.565217
# 278                                   Retina normal    69.565217
# 279                      Normal pregnancy (finding)    69.230769
# 260                                 Abnormal dreams    76.923077
# 261                               Abnormal dreaming    76.923077
# 262                                    ESR abnormal    75.000000
# 263                                   Panoral X-ray    75.000000
# 264                                 Abnormal orgasm    74.074074
# 265                              Abnormal pregnancy    73.333333
# 266                    Abnormal pregnancy (finding)    73.333333
# 267                         Abnormal gait (finding)    72.000000
# 268                                   Abnormal fear    72.000000
# 269                                   Abnormal gait    72.000000
# 250                   Renal hypertension (disorder)    76.923077
# 251                              Renal hypertension    76.923077
# 252                Maternal hypertension (disorder)    76.190476
# 253                           Maternal hypertension    76.190476
# 254                             Hypnotic withdrawal    75.000000
# 255                  Hypnotic withdrawal (disorder)    75.000000
# 256                  Portal hypertension (disorder)    75.000000
# 257                             Portal hypertension    75.000000
# 258                          Nocturnal hypertension    74.418605
# 259                       PHT - Portal hypertension    74.418605
#
#                    origin
# 290  Levenshtein_distance
# 291  Levenshtein_distance
# 292  Levenshtein_distance
# 293  Levenshtein_distance
# 294  Levenshtein_distance
# 295  Levenshtein_distance
# 296  Levenshtein_distance
# 297  Levenshtein_distance
# 298  Levenshtein_distance
# 299  Levenshtein_distance
# 280  Levenshtein_distance
# 281  Levenshtein_distance
# 282  Levenshtein_distance
# 283  Levenshtein_distance
# 284  Levenshtein_distance
# 285  Levenshtein_distance
# 286  Levenshtein_distance
# 287  Levenshtein_distance
# 288  Levenshtein_distance
# 289  Levenshtein_distance
# 270  Levenshtein_distance
# 271  Levenshtein_distance
# 272  Levenshtein_distance
# 273  Levenshtein_distance
# 274  Levenshtein_distance
# 275  Levenshtein_distance
# 276  Levenshtein_distance
# 277  Levenshtein_distance
# 278  Levenshtein_distance
# 279  Levenshtein_distance
# 260  Levenshtein_distance
# 261  Levenshtein_distance
# 262  Levenshtein_distance
# 263  Levenshtein_distance
# 264  Levenshtein_distance
# 265  Levenshtein_distance
# 266  Levenshtein_distance
# 267  Levenshtein_distance
# 268  Levenshtein_distance
# 269  Levenshtein_distance
# 250  Levenshtein_distance
# 251  Levenshtein_distance
# 252  Levenshtein_distance
# 253  Levenshtein_distance
# 254  Levenshtein_distance
# 255  Levenshtein_distance
# 256  Levenshtein_distance
# 257  Levenshtein_distance
# 258  Levenshtein_distance
# 259  Levenshtein_distance

# %%
df_fuzz_ratio=df_sorted

# %% [markdown]
# # BioWordVec

# %%
# Запускать, если не запускается перед этим Levenshtein:
voc1_df['concept_name_processed'] = voc1_df['concept_name_processed'].apply(lambda x: sorted(x))
voc2_df['concept_name_processed'] = voc2_df['concept_name_processed'].apply(lambda x: x.strip("[]").replace("'", "").split(', '))
voc2_df['concept_name_processed'] = voc2_df['concept_name_processed'].apply(lambda x: sorted(x))

# %%
# Запускать, если перед этим уже был запущен Levenshtein

voc1_df['concept_name_processed'] = voc1_df['concept_name_processed'].apply(lambda x: sorted(x))
#voc2_df['concept_name_processed'] = voc2_df['concept_name_processed'].apply(lambda x: x.strip("[]").replace("'", "").split(', '))
voc2_df['concept_name_processed'] = voc2_df['concept_name_processed'].apply(lambda x: sorted(x))
#voc1_df['target_concept_id']=0

# %%
import time
import numpy as np
import gensim
from sklearn.metrics.pairwise import cosine_similarity

# Load the pre-trained word embeddings model
model_path = 'H:/BioWordVec_PubMed_MIMICIII_d200.vec.bin'
word2vec_model = gensim.models.KeyedVectors.load_word2vec_format(model_path, binary=True)
start_time = time.time()

# Функция для векторизации текста с использованием BioWordVec
def vectorize_text(text, model):
    tokens = text.split()
    vectors = [model[token] for token in tokens if token in model]
    if vectors:
        return np.mean(vectors, axis=0)  # Усреднение векторов
    else:
        return np.zeros(model.vector_size)  # Возвращает нулевой вектор, если нет известных слов

# Применение функции к медицинским терминам в обоих наборах данных
voc1_df['voc1_vector'] = voc1_df['concept_name_processed'].apply(lambda x: vectorize_text(' '.join(x), word2vec_model))
voc2_df['voc2_vector'] = voc2_df['concept_name_processed'].apply(lambda x: vectorize_text(' '.join(x), word2vec_model))

# Удаление строк с отсутствующими векторами
voc1_df = voc1_df.dropna(subset=['voc1_vector'])
voc2_df = voc2_df.dropna(subset=['voc2_vector'])

# %%
start_time = time.time()

num_top_matches = 10

v1 = np.vstack(voc1_df['voc1_vector'])
v2 = np.vstack(voc2_df['voc2_vector'])
similarity = cosine_similarity(v1, v2)
tops = (-similarity).argsort()[:, :num_top_matches]

results_df = pd.concat(     # concat (axis = 0) the list of data frames
    [pd.concat( # generate a list of data frames by concatenating (axis = 1) selected rows and cols from voc1 and voc2
        [voc1_df.loc[[i], ['concept_name', 'concept_id']].reset_index(drop=True),  # for each target concept from voc_1
         voc2_df.loc[[t], ['concept_id', 'concept_name']].reset_index(drop=True),        # add potential mapping match from voc_2
         pd.Series(similarity[i][t], name='Similarity')], axis= 1)                       # and similarity value
     for i in range(0, len(voc1_df)) for t in tops[i]]                                   # `i` - target vocabulary index, `t` - index in top similarity array
).reset_index(drop=True)

elapsed_time = (time.time() - start_time) / 60
print(f"Total elapsed time: {elapsed_time:.1f} minutes")
# Out:
# Total elapsed time: 7.7 minutes

# %%
# Old working but very slow code

# results = []
# num_top_matches = 10

# for voc1_index, voc1_row in voc1_df.iterrows():
#     voc1_name = voc1_row['concept_name']
#     voc1_vector = voc1_row['voc1_vector']
#     voc1_concept_id = voc1_row['concept_id']

#     similarities = []
#     for voc2_index, voc2_row in voc2_df.iterrows():
#         voc2_name = voc2_row['concept_name']  # Сохраняем concept_id
#         voc2_concept_id = voc2_row['concept_id']
#         voc2_vector = voc2_row['voc2_vector']

#         if voc1_vector is not None and voc2_vector is not None:
#             similarity = cosine_similarity([voc1_vector], [voc2_vector])[0][0]
#             similarities.append((voc2_name, voc2_concept_id, similarity))

#     similarities.sort(key=lambda x: x[2], reverse=True)
#     top_matches = similarities[:num_top_matches]

#     for voc2_name, voc2_concept_id, similarity in top_matches:
#         results.append((voc1_name, voc1_concept_id, voc2_concept_id, voc2_name, similarity))  # Добавляем voc1_index и voc2_name

#     # Счетчик каждых 10 обработанных строк
#     if (voc1_index + 1) % 10 == 0:
#         elapsed_time = (time.time() - start_time) / 60
#         print(f"Elapsed time: {elapsed_time:.1f} minutes for processed {voc1_index + 1} rows")

        
# # Создать DataFrame с результатами
# columns = ['voc1_name', 'voc1_concept_id', 'voc2_concept_id', 'voc2_name', 'similarity']  # Добавляем 'voc1_index'
# results_df = pd.DataFrame(results, columns=columns)

# elapsed_time = (time.time() - start_time) / 60
# print(f"Total elapsed time: {elapsed_time:.1f} minutes")

# %%
results_df.head(50)
# Out:
#                   concept_name  concept_id  concept_id  \
# 0        17 ketosteroids urine    36312355     4324980
# 1        17 ketosteroids urine    36312355     4324980
# 2        17 ketosteroids urine    36312355     4042261
# 3        17 ketosteroids urine    36312355     4042261
# 4        17 ketosteroids urine    36312355    40480493
# 5        17 ketosteroids urine    36312355     4042261
# 6        17 ketosteroids urine    36312355    37393636
# 7        17 ketosteroids urine    36312355     4246849
# 8        17 ketosteroids urine    36312355    37393169
# 9        17 ketosteroids urine    36312355     4246849
# 10  17,20-desmolase deficiency    35305837     4050324
# 11  17,20-desmolase deficiency    35305837     4050771
# 12  17,20-desmolase deficiency    35305837     4049720
# 13  17,20-desmolase deficiency    35305837     4050928
# 14  17,20-desmolase deficiency    35305837     4052588
# 15  17,20-desmolase deficiency    35305837     4050297
# 16  17,20-desmolase deficiency    35305837     4050297
# 17  17,20-desmolase deficiency    35305837     4052117
# 18  17,20-desmolase deficiency    35305837     4237272
# 19  17,20-desmolase deficiency    35305837     4050323
# 20   21-hydroxylase deficiency    35305840     4028928
# 21   21-hydroxylase deficiency    35305840     4050764
# 22   21-hydroxylase deficiency    35305840     4051375
# 23   21-hydroxylase deficiency    35305840     4166355
# 24   21-hydroxylase deficiency    35305840     4028928
# 25   21-hydroxylase deficiency    35305840     4166355
# 26   21-hydroxylase deficiency    35305840     4338534
# 27   21-hydroxylase deficiency    35305840     4338534
# 28   21-hydroxylase deficiency    35305840     4323827
# 29   21-hydroxylase deficiency    35305840     4028928
# 30      Abdominal wall anomaly    35305665     4113437
# 31      Abdominal wall anomaly    35305665     4113437
# 32      Abdominal wall anomaly    35305665     4113437
# 33      Abdominal wall anomaly    35305665    37310996
# 34      Abdominal wall anomaly    35305665     4097267
# 35      Abdominal wall anomaly    35305665     4097267
# 36      Abdominal wall anomaly    35305665    40486211
# 37      Abdominal wall anomaly    35305665    37310996
# 38      Abdominal wall anomaly    35305665    37310996
# 39      Abdominal wall anomaly    35305665    40486211
# 40    Abducent nerve operation    37521451     4158892
# 41    Abducent nerve operation    37521451     4158892
# 42    Abducent nerve operation    37521451     4158892
# 43    Abducent nerve operation    37521451      375716
# 44    Abducent nerve operation    37521451     4125026
# 45    Abducent nerve operation    37521451     4125026
# 46    Abducent nerve operation    37521451      375716
# 47    Abducent nerve operation    37521451     4302196
# 48    Abducent nerve operation    37521451     4302196
# 49    Abducent nerve operation    37521451     4301734
#
#                                          concept_name  Similarity
# 0   17-Ketosteroids measurement, fractionation, ur...    0.913912
# 1   17-Ketosteroids measurement, fractionation, urine    0.913912
# 2   Urine 17 ketogenic steroid measurement (proced...    0.902799
# 3              Urine 17 ketogenic steroid measurement    0.902799
# 4                  High 17-ketosteroid level in urine    0.892626
# 5                    Urine 17 ketogenic steroid level    0.891024
# 6                    Urine 17 ketogenic steroid level    0.891024
# 7          Urine 18-hydroxycortisol level (procedure)    0.884305
# 8                      Urine 18-hydroxycortisol level    0.884305
# 9                      Urine 18-hydroxycortisol level    0.884305
# 10                    Deficiency of phosphatidolipase    0.911655
# 11           Deficiency of carbamylaspartotranskinase    0.911655
# 12                       Deficiency of glucosulfatase    0.911655
# 13                        Deficiency of thymonuclease    0.911655
# 14                       Deficiency of aldoketomutase    0.911655
# 15                   Deficiency of oximinotransferase    0.911655
# 16        Deficiency of oximinotransferase (disorder)    0.911655
# 17                         Deficiency of desulphinase    0.911655
# 18                 Deficiency of inosinase (disorder)    0.911655
# 19                         Deficiency of monobutyrase    0.911655
# 20                         CAH - desmolase deficiency    0.905537
# 21                    CAH - 17-hydroxylase deficiency    0.891018
# 22                    CAH - 21-hydroxylase deficiency    0.884174
# 23                    CAH - 18-hydroxylase deficiency    0.877972
# 24  Congenital adrenal hyperplasia (CAH)- desmolas...    0.876497
# 25  Aldosterone deficiency due to 18-hydroxysteroi...    0.865066
# 26                  Biotinidase deficiency (disorder)    0.863170
# 27                             Biotinidase deficiency    0.863170
# 28            Sulphoiduronidate sulphatase deficiency    0.862626
# 29  Congenital adrenal hyperplasia - desmolase def...    0.861918
# 30      Congenital anomaly of anterior abdominal wall    0.940928
# 31  Congenital malformation of anterior abdominal ...    0.920819
# 32  Congenital malformation of anterior abdominal ...    0.920819
# 33                       Foetal abdominal wall defect    0.920518
# 34                           Lipoma of abdominal wall    0.920155
# 35                Lipoma of abdominal wall (disorder)    0.920155
# 36                      Haemangioma of abdominal wall    0.920143
# 37             Fetal abdominal wall defect (disorder)    0.916675
# 38                        Fetal abdominal wall defect    0.916675
# 39            Hemangioma of abdominal wall (disorder)    0.914838
# 40                                   Nerve operations    0.939110
# 41                                    Nerve operation    0.939110
# 42                        Nerve operation (procedure)    0.939110
# 43                              Abducent nerve injury    0.904299
# 44        Spinal nerve ganglion operation (procedure)    0.901340
# 45                    Spinal nerve ganglion operation    0.901340
# 46                           Injury to abducent nerve    0.896366
# 47                        Procedure on abducens nerve    0.893655
# 48            Procedure on abducens nerve (procedure)    0.893655
# 49      Transection of supraorbital nerve (procedure)    0.892968

# %%
# Modification to new variant
new_columns = list(results_df.columns)
new_columns[0] = 'voc1_name'
new_columns[1]='voc1_concept_id'
new_columns[2]='voc2_concept_id'
new_columns[3]='voc2_name'
new_columns[4]='similarity'
results_df.columns = new_columns


# Присвойте новый список названий столбцов атрибуту 'columns' DataFrame
#results_df['voc1_concept_id']=0
results_df
# Out:
#                      voc1_name  voc1_concept_id  voc2_concept_id  \
# 0        17 ketosteroids urine         36312355          4324980
# 1        17 ketosteroids urine         36312355          4324980
# 2        17 ketosteroids urine         36312355          4042261
# 3        17 ketosteroids urine         36312355          4042261
# 4        17 ketosteroids urine         36312355         40480493
# ...                        ...              ...              ...
# 19995  Vulval cancer recurrent         36617671         37208178
# 19996  Vulval cancer recurrent         36617671          4312395
# 19997  Vulval cancer recurrent         36617671         45769825
# 19998  Vulval cancer recurrent         36617671         45769825
# 19999  Vulval cancer recurrent         36617671         40487046
#
#                                                voc2_name  similarity
# 0      17-Ketosteroids measurement, fractionation, ur...    0.913912
# 1      17-Ketosteroids measurement, fractionation, urine    0.913912
# 2      Urine 17 ketogenic steroid measurement (proced...    0.902799
# 3                 Urine 17 ketogenic steroid measurement    0.902799
# 4                     High 17-ketosteroid level in urine    0.892626
# ...                                                  ...         ...
# 19995                Recurrent ovarian cancer (disorder)    0.881319
# 19996                      Cancer of vulva, disseminated    0.860730
# 19997  Recurrent primary malignant neoplasm of vulva ...    0.859373
# 19998      Recurrent primary malignant neoplasm of vulva    0.859373
# 19999                                 Carcinoma of vulva    0.855377
#
# [20000 rows x 5 columns]

# %%
# Output the results as a Pandas dataframe
df_sorted = results_df.sort_values(by=['voc1_name', 'similarity'], ascending=False)
df_sorted['origin']='BioWordVec'
df_sorted.to_csv('final_table'+'_biowordvec.csv', index=False)
df_sorted.head(50)
# Out:
#                                                voc1_name  voc1_concept_id  \
# 19990                            Vulval cancer recurrent         36617671
# 19991                            Vulval cancer recurrent         36617671
# 19992                            Vulval cancer recurrent         36617671
# 19993                            Vulval cancer recurrent         36617671
# 19994                            Vulval cancer recurrent         36617671
# 19995                            Vulval cancer recurrent         36617671
# 19996                            Vulval cancer recurrent         36617671
# 19997                            Vulval cancer recurrent         36617671
# 19998                            Vulval cancer recurrent         36617671
# 19999                            Vulval cancer recurrent         36617671
# 19980                           Vulval cancer metastatic         36617670
# 19981                           Vulval cancer metastatic         36617670
# 19982                           Vulval cancer metastatic         36617670
# 19983                           Vulval cancer metastatic         36617670
# 19984                           Vulval cancer metastatic         36617670
# 19985                           Vulval cancer metastatic         36617670
# 19986                           Vulval cancer metastatic         36617670
# 19987                           Vulval cancer metastatic         36617670
# 19988                           Vulval cancer metastatic         36617670
# 19989                           Vulval cancer metastatic         36617670
# 19970      Vitamin A deficiency related corneal disorder         35606879
# 19971      Vitamin A deficiency related corneal disorder         35606879
# 19972      Vitamin A deficiency related corneal disorder         35606879
# 19973      Vitamin A deficiency related corneal disorder         35606879
# 19974      Vitamin A deficiency related corneal disorder         35606879
# 19975      Vitamin A deficiency related corneal disorder         35606879
# 19976      Vitamin A deficiency related corneal disorder         35606879
# 19977      Vitamin A deficiency related corneal disorder         35606879
# 19978      Vitamin A deficiency related corneal disorder         35606879
# 19979      Vitamin A deficiency related corneal disorder         35606879
# 19960  Vitamin A deficiency related conjunctival diso...         35606850
# 19961  Vitamin A deficiency related conjunctival diso...         35606850
# 19962  Vitamin A deficiency related conjunctival diso...         35606850
# 19963  Vitamin A deficiency related conjunctival diso...         35606850
# 19964  Vitamin A deficiency related conjunctival diso...         35606850
# 19965  Vitamin A deficiency related conjunctival diso...         35606850
# 19966  Vitamin A deficiency related conjunctival diso...         35606850
# 19967  Vitamin A deficiency related conjunctival diso...         35606850
# 19968  Vitamin A deficiency related conjunctival diso...         35606850
# 19969  Vitamin A deficiency related conjunctival diso...         35606850
# 19950                  Vital dye staining cornea present         36315210
# 19951                  Vital dye staining cornea present         36315210
# 19952                  Vital dye staining cornea present         36315210
# 19953                  Vital dye staining cornea present         36315210
# 19954                  Vital dye staining cornea present         36315210
# 19955                  Vital dye staining cornea present         36315210
# 19956                  Vital dye staining cornea present         36315210
# 19957                  Vital dye staining cornea present         36315210
# 19958                  Vital dye staining cornea present         36315210
# 19959                  Vital dye staining cornea present         36315210
#
#        voc2_concept_id                                          voc2_name  \
# 19990           195197                              Primary vulval cancer
# 19991          4178959                                    Cancer of vulva
# 19992           764225                                   Recurrent cancer
# 19993          4313226                         Cancer metastatic to vulva
# 19994         37208178                           Recurrent ovarian cancer
# 19995         37208178                Recurrent ovarian cancer (disorder)
# 19996          4312395                      Cancer of vulva, disseminated
# 19997         45769825  Recurrent primary malignant neoplasm of vulva ...
# 19998         45769825      Recurrent primary malignant neoplasm of vulva
# 19999         40487046                                 Carcinoma of vulva
# 19980          4313226                         Cancer metastatic to vulva
# 19981           195197                              Primary vulval cancer
# 19982         36684951                           Metastatic penile cancer
# 19983          4178959                                    Cancer of vulva
# 19984           432851                                  Metastatic cancer
# 19985          4091766                        Cancer metastatic to cervix
# 19986          4171273                               Cancer anal melanoma
# 19987         36683301                       Metastatic colorectal cancer
# 19988          4313225                        Cancer metastatic to vagina
# 19989          4196262                         Metastatic prostate cancer
# 19970           372293          Vitamin A deficiency with corneal xerosis
# 19971           372293  Vitamin A deficiency with corneal xerosis (dis...
# 19972           436664     Vitamin A deficiency with ocular manifestation
# 19973           436664  Vitamin A deficiency with ocular manifestation...
# 19974         37116565  Corneal ulcer due to vitamin A deficiency (dis...
# 19975         37116565          Corneal ulcer due to vitamin A deficiency
# 19976           376374            Vitamin A deficiency with keratomalacia
# 19977           376374  Vitamin A deficiency with keratomalacia (disor...
# 19978         37017792      Gingival disorder due to vitamin C deficiency
# 19979           378395  Vitamin A deficiency with xerophthalmic cornea...
# 19960           436664  Vitamin A deficiency with ocular manifestation...
# 19961           436664     Vitamin A deficiency with ocular manifestation
# 19962           376663  Vitamin A deficiency with conjunctival xerosis...
# 19963           376663     Vitamin A deficiency with conjunctival xerosis
# 19964         37017792      Gingival disorder due to vitamin C deficiency
# 19965          4035837                   Disorder of vitamin A (disorder)
# 19966          4035837                              Disorder of vitamin A
# 19967          4239697            Vitamin A deficiency with xerophthalmia
# 19968          4239697  Vitamin A deficiency with xerophthalmia (disor...
# 19969           376374            Vitamin A deficiency with keratomalacia
# 19950          4191229                     Fluorescein staining of cornea
# 19951          4191229           Fluorescein staining of cornea (finding)
# 19952          4014629                                     Vital staining
# 19953          4190259            Fluorescein staining of eye (procedure)
# 19954          4190259                        Fluorescein staining of eye
# 19955          4014629                              Vital staining method
# 19956          4014629                                        Vital stain
# 19957         44784605                  Green intrinsic staining of tooth
# 19958         44784605       Green intrinsic staining of tooth (disorder)
# 19959          4215668               Trypan blue staining of lens capsule
#
#        similarity      origin
# 19990    0.918315  BioWordVec
# 19991    0.901247  BioWordVec
# 19992    0.899003  BioWordVec
# 19993    0.885942  BioWordVec
# 19994    0.881319  BioWordVec
# 19995    0.881319  BioWordVec
# 19996    0.860730  BioWordVec
# 19997    0.859373  BioWordVec
# 19998    0.859373  BioWordVec
# 19999    0.855377  BioWordVec
# 19980    0.959047  BioWordVec
# 19981    0.919263  BioWordVec
# 19982    0.917173  BioWordVec
# 19983    0.917103  BioWordVec
# 19984    0.911498  BioWordVec
# 19985    0.908583  BioWordVec
# 19986    0.906392  BioWordVec
# 19987    0.901959  BioWordVec
# 19988    0.901112  BioWordVec
# 19989    0.889729  BioWordVec
# 19970    0.935039  BioWordVec
# 19971    0.935039  BioWordVec
# 19972    0.934601  BioWordVec
# 19973    0.934601  BioWordVec
# 19974    0.924866  BioWordVec
# 19975    0.924866  BioWordVec
# 19976    0.924507  BioWordVec
# 19977    0.924507  BioWordVec
# 19978    0.922695  BioWordVec
# 19979    0.921789  BioWordVec
# 19960    0.945962  BioWordVec
# 19961    0.945962  BioWordVec
# 19962    0.935464  BioWordVec
# 19963    0.935464  BioWordVec
# 19964    0.930304  BioWordVec
# 19965    0.926626  BioWordVec
# 19966    0.926626  BioWordVec
# 19967    0.922773  BioWordVec
# 19968    0.922773  BioWordVec
# 19969    0.922218  BioWordVec
# 19950    0.906290  BioWordVec
# 19951    0.906290  BioWordVec
# 19952    0.889221  BioWordVec
# 19953    0.877128  BioWordVec
# 19954    0.877128  BioWordVec
# 19955    0.868990  BioWordVec
# 19956    0.862239  BioWordVec
# 19957    0.860788  BioWordVec
# 19958    0.860788  BioWordVec
# 19959    0.854884  BioWordVec

# %%
df_biowordvec=df_sorted

# %% [markdown]
# # Final merge tables and remove duplicates

# %%
import datetime
current_datetime = datetime.datetime.now()
current_date = current_datetime.date()

# %%
df_tfidf = pd.read_csv('final_table_tfidf.csv')
df_tfidf.drop_duplicates(subset=['voc1_name', 'voc2_concept_id'], inplace=True)
df_tfidf
# Out:
#                      voc1_name  voc1_concept_id  voc2_concept_id  \
# 0      Vulval cancer recurrent         36617671           195197
# 1      Vulval cancer recurrent         36617671           764225
# 2      Vulval cancer recurrent         36617671           442259
# 3      Vulval cancer recurrent         36617671         37208178
# 5      Vulval cancer recurrent         36617671          4172084
# ...                        ...              ...              ...
# 19990    17 ketosteroids urine         36312355          4018340
# 19992    17 ketosteroids urine         36312355          4035824
# 19993    17 ketosteroids urine         36312355         40480493
# 19996    17 ketosteroids urine         36312355          4017199
# 19998    17 ketosteroids urine         36312355          4036649
#
#                                             voc2_name  similarity origin
# 0                               Primary vulval cancer    0.777719  TfIDF
# 1                                    Recurrent cancer    0.740397  TfIDF
# 2                                     Vulval disorder    0.583841  TfIDF
# 3                 Recurrent ovarian cancer (disorder)    0.579575  TfIDF
# 5                                       Vulval biopsy    0.564193  TfIDF
# ...                                               ...         ...    ...
# 19990         17-Ketosteroids measurement (procedure)    0.878312  TfIDF
# 19992                     Disorder of 17-ketosteroids    0.858936  TfIDF
# 19993              High 17-ketosteroid level in urine    0.850166  TfIDF
# 19996  17-Ketosteroids measurement, total (procedure)    0.809079  TfIDF
# 19998                 Increased 17-ketosteroids level    0.791854  TfIDF
#
# [11982 rows x 6 columns]

# %%
df_fuzz_ratio = pd.read_csv('final_table_fuzz_ratio.csv')
df_fuzz_ratio.drop_duplicates(subset=['voc1_name', 'voc2_concept_id'], inplace=True)
df_fuzz_ratio
# Out:
#                      voc1_name  voc1_concept_id  voc2_concept_id  \
# 0        17 ketosteroids urine         36312355          4055428
# 1        17 ketosteroids urine         36312355         37393311
# 3        17 ketosteroids urine         36312355          4150637
# 4        17 ketosteroids urine         36312355         37393634
# 5        17 ketosteroids urine         36312355          4055829
# ...                        ...              ...              ...
# 19995  Vulval cancer recurrent         36617671           443390
# 19996  Vulval cancer recurrent         36617671           198984
# 19997  Vulval cancer recurrent         36617671           440637
# 19998  Vulval cancer recurrent         36617671          4178959
# 19999  Vulval cancer recurrent         36617671          4190765
#
#                                voc2_name  min_distance                origin
# 0      Urine steroid profile (procedure)             7  Levenshtein_distance
# 1                  Urine steroid profile             7  Levenshtein_distance
# 3                      Urine ketone test             8  Levenshtein_distance
# 4                      Urine ketone test             8  Levenshtein_distance
# 5                  Urine ketone test = +             8  Levenshtein_distance
# ...                                  ...           ...                   ...
# 19995                      Rectal cancer             9  Levenshtein_distance
# 19996                    Cervical cancer            10  Levenshtein_distance
# 19997                    Recurrent fever            10  Levenshtein_distance
# 19998                    Cancer of vulva            10  Levenshtein_distance
# 19999           Recurrent ventral hernia            10  Levenshtein_distance
#
# [13183 rows x 6 columns]

# %%
df_biowordvec = pd.read_csv('final_table_biowordvec.csv')
df_biowordvec.drop_duplicates(subset=['voc1_name', 'voc2_concept_id'], inplace=True)
df_biowordvec
# Out:
#                      voc1_name  voc1_concept_id  voc2_concept_id  \
# 0      Vulval cancer recurrent         36617671           195197
# 1      Vulval cancer recurrent         36617671          4178959
# 2      Vulval cancer recurrent         36617671           764225
# 3      Vulval cancer recurrent         36617671          4313226
# 4      Vulval cancer recurrent         36617671         37208178
# ...                        ...              ...              ...
# 19992    17 ketosteroids urine         36312355          4042261
# 19994    17 ketosteroids urine         36312355         40480493
# 19996    17 ketosteroids urine         36312355         37393636
# 19997    17 ketosteroids urine         36312355          4246849
# 19998    17 ketosteroids urine         36312355         37393169
#
#                                                voc2_name  similarity  \
# 0                                  Primary vulval cancer    0.918315
# 1                                        Cancer of vulva    0.901247
# 2                                       Recurrent cancer    0.899003
# 3                             Cancer metastatic to vulva    0.885942
# 4                               Recurrent ovarian cancer    0.881319
# ...                                                  ...         ...
# 19992  Urine 17 ketogenic steroid measurement (proced...    0.902799
# 19994                 High 17-ketosteroid level in urine    0.892626
# 19996                   Urine 17 ketogenic steroid level    0.891024
# 19997         Urine 18-hydroxycortisol level (procedure)    0.884305
# 19998                     Urine 18-hydroxycortisol level    0.884305
#
#            origin
# 0      BioWordVec
# 1      BioWordVec
# 2      BioWordVec
# 3      BioWordVec
# 4      BioWordVec
# ...           ...
# 19992  BioWordVec
# 19994  BioWordVec
# 19996  BioWordVec
# 19997  BioWordVec
# 19998  BioWordVec
#
# [11150 rows x 6 columns]

# %%
# Объединить таблицы, устранить дублирующие строки с одинаковыми парами сорс-код и potential_concept_id
table_name = 'combined_table_'+str(current_date)+'.csv'
df_exp = pd.concat([df_tfidf, df_biowordvec, df_fuzz_ratio])
df_exp = df_exp.sort_values(by=['voc1_name']) 
df_exp
# Out:
#                      voc1_name  voc1_concept_id  voc2_concept_id  \
# 4        17 ketosteroids urine         36312355         37393634
# 8        17 ketosteroids urine         36312355          4018340
# 7        17 ketosteroids urine         36312355          4042261
# 5        17 ketosteroids urine         36312355          4055829
# 3        17 ketosteroids urine         36312355          4150637
# ...                        ...              ...              ...
# 4      Vulval cancer recurrent         36617671         37208178
# 6      Vulval cancer recurrent         36617671          4312395
# 7      Vulval cancer recurrent         36617671         45769825
# 0      Vulval cancer recurrent         36617671           195197
# 19999  Vulval cancer recurrent         36617671          4190765
#
#                                                voc2_name  similarity  \
# 4                                      Urine ketone test         NaN
# 8                            17-Ketosteroids measurement         NaN
# 7                         Urine 17 ketogenic steroid lev         NaN
# 5                                  Urine ketone test = +         NaN
# 3                                      Urine ketone test         NaN
# ...                                                  ...         ...
# 4                               Recurrent ovarian cancer    0.881319
# 6                          Cancer of vulva, disseminated    0.860730
# 7      Recurrent primary malignant neoplasm of vulva ...    0.859373
# 0                                  Primary vulval cancer    0.918315
# 19999                           Recurrent ventral hernia         NaN
#
#                      origin  min_distance
# 4      Levenshtein_distance           8.0
# 8      Levenshtein_distance           8.0
# 7      Levenshtein_distance           8.0
# 5      Levenshtein_distance           8.0
# 3      Levenshtein_distance           8.0
# ...                     ...           ...
# 4                BioWordVec           NaN
# 6                BioWordVec           NaN
# 7                BioWordVec           NaN
# 0                BioWordVec           NaN
# 19999  Levenshtein_distance          10.0
#
# [36315 rows x 7 columns]

# %%
# Группировка и создание поля flag
grouped = df_exp.groupby(['voc1_name', 'voc2_concept_id'])

def combine_origin(group):
    if len(group) > 1:
        group['flag'] = ' / '.join(sorted(group['origin']))
        return group.iloc[:1]  # оставляем только одну строку для объединенных
    else:
        group['flag'] = group['origin'].iloc[0]
        return group

df_exp = grouped.apply(combine_origin).reset_index(drop=True)
df_exp.drop(['origin'], axis=1, inplace=True)

# Вывод результата
df_exp
# Out:
#                      voc1_name  voc1_concept_id  voc2_concept_id  \
# 0        17 ketosteroids urine         36312355          4017199
# 1        17 ketosteroids urine         36312355          4018340
# 2        17 ketosteroids urine         36312355          4035824
# 3        17 ketosteroids urine         36312355          4036649
# 4        17 ketosteroids urine         36312355          4042261
# ...                        ...              ...              ...
# 28537  Vulval cancer recurrent         36617671         37208178
# 28538  Vulval cancer recurrent         36617671         37208260
# 28539  Vulval cancer recurrent         36617671         40487046
# 28540  Vulval cancer recurrent         36617671         44808049
# 28541  Vulval cancer recurrent         36617671         45769825
#
#                                                voc2_name  similarity  \
# 0         17-Ketosteroids measurement, total (procedure)    0.809079
# 1                            17-Ketosteroids measurement         NaN
# 2                            Disorder of 17-ketosteroids    0.858936
# 3                        Increased 17-ketosteroids level    0.791854
# 4                         Urine 17 ketogenic steroid lev         NaN
# ...                                                  ...         ...
# 28537                Recurrent ovarian cancer (disorder)    0.579575
# 28538                           Recurrent renal calculus         NaN
# 28539                                 Carcinoma of vulva    0.855377
# 28540                                Recurrent leg ulcer         NaN
# 28541  Recurrent primary malignant neoplasm of vulva ...    0.859373
#
#        min_distance                               flag
# 0               NaN                              TfIDF
# 1               8.0       Levenshtein_distance / TfIDF
# 2               NaN                              TfIDF
# 3               NaN                              TfIDF
# 4               8.0  BioWordVec / Levenshtein_distance
# ...             ...                                ...
# 28537           NaN                 BioWordVec / TfIDF
# 28538           9.0               Levenshtein_distance
# 28539           NaN                         BioWordVec
# 28540           9.0               Levenshtein_distance
# 28541           NaN                         BioWordVec
#
# [28542 rows x 7 columns]

# %%
result = df_exp.groupby(['flag']).size().sort_values(ascending=False).reset_index(name='count')
result
# Out:
#                                         flag  count
# 0                       Levenshtein_distance   9294
# 1                                      TfIDF   6723
# 2                                 BioWordVec   6383
# 3                         BioWordVec / TfIDF   2253
# 4  BioWordVec / Levenshtein_distance / TfIDF   1631
# 5               Levenshtein_distance / TfIDF   1375
# 6          BioWordVec / Levenshtein_distance    883

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\covib\anaconda3\lib\site-packages (3.0.10)
# Requirement already satisfied: et_xmlfile in c:\users\covib\anaconda3\lib\site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: tensorflow-examples 37df0b9a2f7240831642cea4380e4f7ec33bee83- has a non-standard version number. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of tensorflow-examples or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
df_exp = df_exp.drop_duplicates(subset=['voc1_name', 'voc2_concept_id'])
df_exp.to_excel('my_table_30112023.xlsx', index=False)

# %%
df_exp = pd.read_excel('my_table_30112023.xlsx')
df_exp
# Out:
#                      voc1_name  voc1_concept_id  voc2_concept_id  \
# 0        17 ketosteroids urine         36312355          4017199
# 1        17 ketosteroids urine         36312355          4018340
# 2        17 ketosteroids urine         36312355          4035824
# 3        17 ketosteroids urine         36312355          4036649
# 4        17 ketosteroids urine         36312355          4042261
# ...                        ...              ...              ...
# 28537  Vulval cancer recurrent         36617671         37208178
# 28538  Vulval cancer recurrent         36617671         37208260
# 28539  Vulval cancer recurrent         36617671         40487046
# 28540  Vulval cancer recurrent         36617671         44808049
# 28541  Vulval cancer recurrent         36617671         45769825
#
#                                                voc2_name  similarity  \
# 0         17-Ketosteroids measurement, total (procedure)    0.809079
# 1                            17-Ketosteroids measurement         NaN
# 2                            Disorder of 17-ketosteroids    0.858936
# 3                        Increased 17-ketosteroids level    0.791854
# 4                         Urine 17 ketogenic steroid lev         NaN
# ...                                                  ...         ...
# 28537                Recurrent ovarian cancer (disorder)    0.579575
# 28538                           Recurrent renal calculus         NaN
# 28539                                 Carcinoma of vulva    0.855377
# 28540                                Recurrent leg ulcer         NaN
# 28541  Recurrent primary malignant neoplasm of vulva ...    0.859373
#
#        min_distance                               flag
# 0               NaN                              TfIDF
# 1               8.0       Levenshtein_distance / TfIDF
# 2               NaN                              TfIDF
# 3               NaN                              TfIDF
# 4               8.0  BioWordVec / Levenshtein_distance
# ...             ...                                ...
# 28537           NaN                 BioWordVec / TfIDF
# 28538           9.0               Levenshtein_distance
# 28539           NaN                         BioWordVec
# 28540           9.0               Levenshtein_distance
# 28541           NaN                         BioWordVec
#
# [28542 rows x 7 columns]

# %%
#To download table into database scheme 
login="dev_test5"
passw = "7hGg365$%fhhTfr$dJ"
engine = create_engine('postgresql://{}:{}@ovh07.odysseusinc.com:5555/postgres'.format(login, passw))
table_name = 'am_gpt_meddra_pt_first_2000_051223_out_75_full_variant'
df_exp.to_sql(table_name, engine, if_exists='replace', index=False)
print(f'Import {table_name} was sucessful!')
# Out:
# Import am_gpt_meddra_pt_first_2000_051223_out_75_full_variant was sucessful!

# %%
combined_df = df_exp.copy()
combined_df['question'] = 'Pick the best semantic match for '
combined_df = combined_df[['question'] + [col for col in combined_df.columns if col != 'question']]
combined_df.rename(columns={'voc1_name': 'source_code_description', 'voc2_concept_id': 'potential_target_concept_id'}, inplace=True)
combined_df = combined_df.sort_values(by=['source_code_description', 'potential_target_concept_id'])
combined_df = combined_df[['question', 'source_code_description', 'potential_target_concept_id']]
combined_df['chatgptreply']=''
combined_df['target_concept_id'] = None
combined_df['log_id']=None
combined_df['target_concept_id'] = combined_df['target_concept_id'].astype('Int64')
combined_df['log_id'] = combined_df['log_id'].astype('Int64')
combined_df
# Out:
#                                 question  source_code_description  \
# 0      Pick the best semantic match for     17 ketosteroids urine
# 1      Pick the best semantic match for     17 ketosteroids urine
# 2      Pick the best semantic match for     17 ketosteroids urine
# 3      Pick the best semantic match for     17 ketosteroids urine
# 4      Pick the best semantic match for     17 ketosteroids urine
# ...                                  ...                      ...
# 28537  Pick the best semantic match for   Vulval cancer recurrent
# 28538  Pick the best semantic match for   Vulval cancer recurrent
# 28539  Pick the best semantic match for   Vulval cancer recurrent
# 28540  Pick the best semantic match for   Vulval cancer recurrent
# 28541  Pick the best semantic match for   Vulval cancer recurrent
#
#        potential_target_concept_id chatgptreply  target_concept_id  log_id
# 0                          4017199                            <NA>    <NA>
# 1                          4018340                            <NA>    <NA>
# 2                          4035824                            <NA>    <NA>
# 3                          4036649                            <NA>    <NA>
# 4                          4042261                            <NA>    <NA>
# ...                            ...          ...                ...     ...
# 28537                     37208178                            <NA>    <NA>
# 28538                     37208260                            <NA>    <NA>
# 28539                     40487046                            <NA>    <NA>
# 28540                     44808049                            <NA>    <NA>
# 28541                     45769825                            <NA>    <NA>
#
# [28542 rows x 6 columns]

# %%
#To download table into database scheme 
login="dev_test5"
passw = "7hGg365$%fhhTfr$dJ"
engine = create_engine('postgresql://{}:{}@ovh07.odysseusinc.com:5555/postgres'.format(login, passw))
table_name = 'am_gpt_meddra_pt_first_2000_051223_out_75'
combined_df.to_sql(table_name, engine, if_exists='replace', index=False)
print(f'Import {table_name} was sucessful!')
# Out:
# Import am_gpt_meddra_pt_first_2000_051223_out_75 was sucessful!
